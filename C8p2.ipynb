# %%
#task1:
#import neccesary libraries
import pandas as pd
import numpy as np

# %%
#reading the file
Car_data=pd.read_csv("C:/Users/91918/OneDrive/Desktop/SUDHEERA/DataScience with Gen Ai/Course-8/Sprint-2/DS1_C8_S2_SmartCarRiding_Data_Practice.csv")
Car_data
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
print("Number of rows:",Car_data.shape[0])
print("Number of columns:",Car_data.shape[1])
print("Column names:",Car_data.columns.tolist())

# Extract the 'fare_amount' column
fare_amount_column = Car_data['fare_amount']
# Out:
# Number of rows: 200000
# Number of columns: 9
# Column names: ['Index', 'key', 'fare_amount', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'passenger_count']

# %%
#task2
import matplotlib.pyplot as plt
plt.boxplot(Car_data["fare_amount"])
plt.title("check outliers of fare_amount")
plt.ylabel("fare_amount")
plt.show()

# %%
import pandas as pd
import numpy as np

def treat_outliers_iqr(data, column_name):

    Q1 = data[column_name].quantile(0.25)
    Q3 = data[column_name].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

 
    data[column_name] = np.where(data[column_name] < lower_bound, lower_bound, data[column_name])
    data[column_name] = np.where(data[column_name] > upper_bound, upper_bound, data[column_name])

    return data

Car_data = treat_outliers_iqr(Car_data, 'fare_amount')

# %%
import matplotlib.pyplot as plt
plt.boxplot(Car_data["fare_amount"])
plt.title("check outliers of fare_amount")
plt.ylabel("fare_amount")
plt.show()

# %%
#task3
import numpy
import matplotlib.pyplot as plt
num = [10, 15, 30, 200, 1000, 5000, 10000, 50000, 100000]
data_s = []
sample_df = pd.DataFrame()
fig, ax = plt.subplots(2, 4,figsize= (15,8))
for i in num:
    sample_df = Car_data.sample(n=i, random_state = 1, replace = True)
    data_s.append(sample_df["fare_amount"].tolist())
#print(data_s)
k= 0
for i in range(0,2):
    for j in range(0,4):
        ax[i,j].hist(data_s[k], 5, density = True)
        ax[i,j].set_title(label = "Sample Size ="+str(len(data_s[k])))
        k = k +1

plt.show()

# %%
import pandas as pd
import numpy as np

#Task4:
sample_size = 200

# Extract a random sample with replacement
sample_data = Car_data.sample(n=sample_size, replace=True)
sample_data
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 75012   37165939  44:00.0         5.30  2011-03-05 15:44:00 UTC
# 147828  20090669  01:00.0         6.00  2013-12-17 19:01:00 UTC
# 187378  35898073  09:20.0         9.50  2012-09-17 20:09:20 UTC
# 93110   15524816  07:00.0         3.70  2010-04-15 21:07:00 UTC
# 172508  36090596  34:00.0         6.90  2009-03-12 09:34:00 UTC
# ...          ...      ...          ...                      ...
# 60491   50727989  29:00.0         5.70  2010-05-23 03:29:00 UTC
# 190280  51802030  56:00.0        10.00  2013-05-18 12:56:00 UTC
# 67934    1456709  42:00.0         4.50  2014-10-30 23:42:00 UTC
# 61609   53866654  04:00.0         8.50  2012-07-10 19:04:00 UTC
# 151179  46497945  30:33.0        22.25  2014-11-23 03:30:33 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 75012         -73.999382        40.733997         -73.997070
# 147828        -73.973833        40.764202         -73.978765
# ...

# %%
#task5:
sample_size = 200
sample_df = Car_data.sample(n=sample_size, replace=True)

# Calculate central tendency and dispersion for the entire dataset
entire_data_mean = Car_data['fare_amount'].mean()
entire_data_median = Car_data['fare_amount'].median()
entire_data_std = Car_data['fare_amount'].std()
entire_data_var = Car_data['fare_amount'].var()

# Calculate central tendency and dispersion for the sample
sample_mean = sample_df['fare_amount'].mean()
sample_median = sample_df['fare_amount'].median()
sample_std = sample_df['fare_amount'].std()
sample_var = sample_df['fare_amount'].var()

# Compare the measures
print("Entire Dataset:")
print("Mean:", entire_data_mean)
print("Median:", entire_data_median)
print("Standard Deviation:", entire_data_std)
print("Variance:", entire_data_var)

print("\nSample Dataset:")
print("Mean:", sample_mean)
print("Median:", sample_median)
print("Standard Deviation:", sample_std)
print("Variance:", sample_var)
# Out:
# Entire Dataset:
# Mean: 10.08112085
# Median: 8.5
# Standard Deviation: 5.440253031795867
# Variance: 29.596353049964122
#
# Sample Dataset:
# Mean: 10.553850000000002
# Median: 8.5
# Standard Deviation: 5.6214855846468135
# Variance: 31.601100178391928

# %% [markdown]
# mean,median,stdv are approximately equal for both dataset and sample distribution,which implies rhat the population data and sample data wth sample size 40 both are normally distributed.
# sample mean nearly equal. this is second rule of cental limit theorem
